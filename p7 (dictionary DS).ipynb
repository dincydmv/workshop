# %%
mydictionary={}
print(mydictionary)
# Out:
# {}

# %%
print(type(mydictionary))
# Out:
# <class 'dict'>

# %%
dict={'First':'python','second':'is'}
print(dict)
# Out:
# {'First': 'python', 'second': 'is'}

# %%
print(len(dict))
# Out:
# 2

# %%
dict={'First':'python','second':'is'}
dict["second"]='hi'
dict['third']='no'
dict['fourth']='nice'
dict
# Out:
# {'First': 'python', 'second': 'hi', 'third': 'no', 'fourth': 'nice'}

# %%
dict={'First': 'python', 'second': 'hi', 'third': 'no', 'fourth': 'nice'}
dict.update({'fifth':'java'})
print(dict)
# Out:
# {'First': 'python', 'second': 'hi', 'third': 'no', 'fourth': 'nice', 'fifth': 'java'}

# %%
dict['second']
# Out:
# 'hi'

# %%
dict={'First': 'python', 'second': 'hi', 'third': 'no', 'fourth': 'nice'}
dict.get('First')
# Out:
# 'python'

# %%
dict.values()
# Out:
# dict_values(['python', 'hi', 'no', 'nice'])

# %%
dict.items()
# Out:
# dict_items([('First', 'python'), ('second', 'hi'), ('third', 'no'), ('fourth', 'nice')])

# %%
dict={'First': 'python', 'second': 'hi', 'third': 'no', 'fourth': 'nice'}
a=dict.pop('fourth')
print("deleted value is",a)
dict
# Out:
# deleted value is nice
# {'First': 'python', 'second': 'hi', 'third': 'no'}

# %%
dict={'First': 'python', 'second': 'hi', 'third': 'no', 'fourth': 'nice'}
dict.popitem()
dict
# Out:
# {'First': 'python', 'second': 'hi', 'third': 'no'}

# %%
dict={'First': 'python', 'second': 'hi', 'third': 'no', 'fourth': 'nice'}
del dict['third']
dict
# Out:
# {'First': 'python', 'second': 'hi', 'fourth': 'nice'}

# %%
dict={'First': 'python', 'second': 'hi', 'third': 'no', 'fourth': 'nice'}
dict.clear()
dict
# Out:
# {}

# %%
tuple=(2,4,8)
tuple
# Out:
# (2, 4, 8)

# %%
dict={1: 'python', 2: 'hi'}
newdict=dict.copy()
newdict
# Out:
# {1: 'python', 2: 'hi'}

# %%
dict={'First': 'python', 'second': 'hi', 'third': 'no', 'fourth': 'nice'}
key='second'
if key in dict:
    print("key exists")
else:
    print("key does not exist")
# Out:
# key exists

# %%
dict={1: 'python', 2: 'hi'}
key=1
if key in dict:
    print("key exists")
else:
    print("key does not exist")
# Out:
# key exists

# %%
dict={1: 'python', 2: 'hi'}
value='python'
if value in dict.values():
    print("key exists")
else:
    print("key does not exist")
# Out:
# key exists

# %%
dict={1: 'python', 2: 'hi'}
dict.values()
# Out:
# dict_values(['python', 'hi'])

# %%
dict={1:'hi',2:'hello',3:'how',4:'are',5:'you'}
key=int(input("enter a number:"))
for key in dict:
    print(key)
# Out:
# enter a number:3
# 1
# 2
# 3
# 4
# 5
